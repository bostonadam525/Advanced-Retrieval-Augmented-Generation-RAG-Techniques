# %% [markdown]
# # Knowledge Graphs for RAG
# * Notebook by Adam Lang
# * Date: 6/7/2024
#
# # Overview
# * This is a notebook based on my experience with the DeepLearning.AI course 'Knowledge Graphs for RAG' with Neo4j.

# %% [markdown]
# # Knowledge Graph Fundamentals
# * Nodes are data records
# * Relationships are also data records.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Graph Construction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Key/Value Properties
# * Each node containes a key/value property.
# * Example we will see below in the grap:
#   1. Node: Person
#   2. Key property: name
#   3. Value property: "Andreas"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Relationships are also data records
# * They have:
#   * Direction
#   * Type
#   * Properties
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### What is a Knowledge Graph?
# 1. Database that stores information in **nodes** and **relationships**
# 2. BOTH nodes and relationships can have **properties**
# 3. Nodes can be given **labels** to group them together semantically.
# 4. Relationships always have a **type** and **direction**

# %% [markdown]
# # Querying Knowledge Graphs
# * See accompanying notebook
